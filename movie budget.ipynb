# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
moviesdf = pd.read_csv('Clean_Final_Data.csv')
moviesdf.head()
# Out:
#       Id              Title     Budget      Revenue  Original Language  \
# 0    862          Toy Story  30000000.0  373554033.0                en
# 1   8844            Jumanji  65000000.0  262797249.0                en
# 2  31357  Waiting to Exhale  16000000.0   81452156.0                en
# 3    949               Heat  60000000.0  187436818.0                en
# 4   9091       Sudden Death  35000000.0   64350171.0                en
#
#    Popularity        Production Countries  \
# 0   21.946943    United States of America
# 1   17.015539    United States of America
# 2    3.859495    United States of America
# 3   17.924927    United States of America
# 4    5.231580    United States of America
#
#                       Production Companies    Genre 1    Genre 2  ...  \
# 0                  Pixar Animation Studios  Animation     Comedy  ...
# 1                         TriStar Pictures  Adventure    Fantasy  ...
# 2   Twentieth Century Fox Film Corporation     Comedy      Drama  ...
# 3                      Regency Enterprises     Action      Crime  ...
# 4                       Universal Pictures     Action  Adventure  ...
#
#      Status                                            Tagline Vote Average  \
# 0  Released                                                NaN          7.7
# 1  Released          Roll the dice and unleash the excitement!          6.9
# 2  Released  Friends are the people who let you be yourself...          6.1
# 3  Released                           A Los Angeles Crime Saga          7.7
# 4  Released                         Terror goes into overtime.          5.5
#
#    Vote Count Unnamed: 18 Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  \
# 0        5415         NaN         NaN          NaN          NaN          NaN
# 1        2413         NaN         NaN          NaN          NaN          NaN
# 2          34         NaN         NaN          NaN          NaN          NaN
# 3        1886         NaN         NaN          NaN          NaN          NaN
# 4         174         NaN         NaN          NaN          NaN          NaN
#
#    Unnamed: 23
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 24 columns]

# %%
moviesdf = moviesdf[['Id', 'Title', ' Budget ', ' Revenue ', 'Original Language',
       'Popularity', 'Production Countries', 'Production Companies', 'Genre 1',
       'Genre 2', 'Genre 3', 'Genre 4', 'Release Date', 'Runtime', 'Status',
       'Tagline', 'Vote Average', 'Vote Count']]
moviesdf
# Out:
#           Id              Title     Budget      Revenue  Original Language  \
# 0        862          Toy Story  30000000.0  373554033.0                en
# 1       8844            Jumanji  65000000.0  262797249.0                en
# 2      31357  Waiting to Exhale  16000000.0   81452156.0                en
# 3        949               Heat  60000000.0  187436818.0                en
# 4       9091       Sudden Death  35000000.0   64350171.0                en
# ...      ...                ...         ...          ...               ...
# 5376   24049   Sivaji: The Boss  12000000.0   19000000.0                ta
# 5377  280422        All at Once    750000.0          3.0                ru
# 5378   62757            Savages    800000.0    1328612.0                en
# 5379   63281        Pro Lyuboff   2000000.0    1268793.0                en
# 5380   63898            Antidur   5000000.0    1413000.0                ru
#
#       Popularity        Production Countries  \
# 0      21.946943    United States of America
# 1      17.015539    United States of America
# 2       3.859495    United States of America
# 3      17.924927    United States of America
# 4       5.231580    United States of America
# ...          ...                         ...
# 5376    1.323587                       India
# 5377    0.201582                      Russia
# 5378    0.903061                         NaN
# 5379    0.121844                      Russia
# 5380    0.039793                      Russia
#
#                          Production Companies    Genre 1    Genre 2   Genre 3  \
# 0                     Pixar Animation Studios  Animation     Comedy    Family
# 1                            TriStar Pictures  Adventure    Fantasy    Family
# 2      Twentieth Century Fox Film Corporation     Comedy      Drama   Romance
# 3                         Regency Enterprises     Action      Crime     Drama
# 4                          Universal Pictures     Action  Adventure  Thriller
# ...                                       ...        ...        ...       ...
# 5376                          AVM Productions     Action     Comedy     Drama
# 5377                  Кинокомпания «Lunapark»      Crime     Comedy       NaN
# 5378                                      NaN     Comedy      Drama       NaN
# 5379                                   Profit    Romance      Drama       NaN
# 5380                                      NaN     Action     Comedy     Crime
#
#        Genre 4 Release Date  Runtime    Status  \
# 0          NaN   10/30/1995     81.0  Released
# 1          NaN   12/15/1995    104.0  Released
# 2          NaN   12/22/1995    127.0  Released
# 3     Thriller   12/15/1995    170.0  Released
# 4          NaN   12/22/1995    106.0  Released
# ...        ...          ...      ...       ...
# 5376       NaN    6/14/2007    185.0  Released
# 5377       NaN     6/5/2014      0.0  Released
# 5378       NaN   11/23/2006    100.0  Released
# 5379       NaN    9/30/2010    107.0  Released
# 5380   Foreign     9/6/2007     91.0  Released
#
#                                                 Tagline  Vote Average  \
# 0                                                   NaN           7.7
# 1             Roll the dice and unleash the excitement!           6.9
# 2     Friends are the people who let you be yourself...           6.1
# 3                              A Los Angeles Crime Saga           7.7
# 4                            Terror goes into overtime.           5.5
# ...                                                 ...           ...
# 5376                                                NaN           6.9
# 5377                                                NaN           6.0
# 5378                                                NaN           5.8
# 5379                                                NaN           4.0
# 5380                                                NaN           1.0
#
#       Vote Count
# 0           5415
# 1           2413
# 2             34
# 3           1886
# 4            174
# ...          ...
# 5376          25
# 5377           4
# 5378           6
# 5379           3
# 5380           1
#
# [5381 rows x 18 columns]

# %%
moviesdf.columns
# Out:
# Index(['Id', 'Title', ' Budget ', ' Revenue ', 'Original Language',
#        'Popularity', 'Production Countries', 'Production Companies', 'Genre 1',
#        'Genre 2', 'Genre 3', 'Genre 4', 'Release Date', 'Runtime', 'Status',
#        'Tagline', 'Vote Average', 'Vote Count'],
#       dtype='object')

# %%
moviesdf.count()
# Out:
# Id                      5381
# Title                   5381
#  Budget                 5381
#  Revenue                5381
# Original Language       5381
# Popularity              5381
# Production Countries    5320
# Production Companies    5200
# Genre 1                 5369
# Genre 2                 4430
# Genre 3                 2808
# Genre 4                  947
# Release Date            5381
# Runtime                 5380
# Status                  5381
# Tagline                 4629
# Vote Average            5381
# Vote Count              5381
# dtype: int64

# %%
moviesdf = moviesdf.drop_duplicates(subset=['Id'])
moviesdf.count()
# Out:
# Id                      5375
# Title                   5375
#  Budget                 5375
#  Revenue                5375
# Original Language       5375
# Popularity              5375
# Production Countries    5314
# Production Companies    5194
# Genre 1                 5363
# Genre 2                 4425
# Genre 3                 2804
# Genre 4                  945
# Release Date            5375
# Runtime                 5374
# Status                  5375
# Tagline                 4625
# Vote Average            5375
# Vote Count              5375
# dtype: int64

# %%
successful_genres = moviesdf[['Id','Genre 1','Genre 2','Genre 3','Genre 4','Popularity',' Budget ', ' Revenue ']].copy()
successful_genres
# Out:
#           Id    Genre 1    Genre 2   Genre 3   Genre 4  Popularity  \
# 0        862  Animation     Comedy    Family       NaN   21.946943
# 1       8844  Adventure    Fantasy    Family       NaN   17.015539
# 2      31357     Comedy      Drama   Romance       NaN    3.859495
# 3        949     Action      Crime     Drama  Thriller   17.924927
# 4       9091     Action  Adventure  Thriller       NaN    5.231580
# ...      ...        ...        ...       ...       ...         ...
# 5376   24049     Action     Comedy     Drama       NaN    1.323587
# 5377  280422      Crime     Comedy       NaN       NaN    0.201582
# 5378   62757     Comedy      Drama       NaN       NaN    0.903061
# 5379   63281    Romance      Drama       NaN       NaN    0.121844
# 5380   63898     Action     Comedy     Crime   Foreign    0.039793
#
#          Budget      Revenue
# 0     30000000.0  373554033.0
# 1     65000000.0  262797249.0
# 2     16000000.0   81452156.0
# 3     60000000.0  187436818.0
# 4     35000000.0   64350171.0
# ...          ...          ...
# 5376  12000000.0   19000000.0
# 5377    750000.0          3.0
# 5378    800000.0    1328612.0
# 5379   2000000.0    1268793.0
# 5380   5000000.0    1413000.0
#
# [5375 rows x 8 columns]

# %%
popular_filmed_countries = moviesdf[['Id','Popularity', 'Production Countries', ' Revenue ']].copy()
popular_filmed_countries
# Out:
#           Id  Popularity        Production Countries     Revenue
# 0        862   21.946943    United States of America  373554033.0
# 1       8844   17.015539    United States of America  262797249.0
# 2      31357    3.859495    United States of America   81452156.0
# 3        949   17.924927    United States of America  187436818.0
# 4       9091    5.231580    United States of America   64350171.0
# ...      ...         ...                         ...          ...
# 5376   24049    1.323587                       India   19000000.0
# 5377  280422    0.201582                      Russia          3.0
# 5378   62757    0.903061                         NaN    1328612.0
# 5379   63281    0.121844                      Russia    1268793.0
# 5380   63898    0.039793                      Russia    1413000.0
#
# [5375 rows x 4 columns]

# %%
budget_influenced_ratings = moviesdf[['Id','Popularity', ' Budget ']].copy()
budget_influenced_ratings
# Out:
#           Id  Popularity     Budget
# 0        862   21.946943  30000000.0
# 1       8844   17.015539  65000000.0
# 2      31357    3.859495  16000000.0
# 3        949   17.924927  60000000.0
# 4       9091    5.231580  35000000.0
# ...      ...         ...         ...
# 5376   24049    1.323587  12000000.0
# 5377  280422    0.201582    750000.0
# 5378   62757    0.903061    800000.0
# 5379   63281    0.121844   2000000.0
# 5380   63898    0.039793   5000000.0
#
# [5375 rows x 3 columns]

# %%
successful_genres.to_csv('successful_genres.csv', index= False)

# %%
moviesdf.to_csv('clean_final_data2.csv', index= False)

# %%
popular_filmed_countries.to_csv('popular_filmed_countries.csv', index= False)

# %%
budget_influenced_ratings.to_csv('budget_influenced_ratings.csv', index= False)
