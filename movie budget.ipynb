# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
moviesdf = pd.read_csv('Clean_Movies_Data.csv')
moviesdf.head()
# Out:
#       Id              Title          Budget           Revenue   \
# 0    862          Toy Story  $30,000,000.00   $373,554,033.00
# 1   8844            Jumanji  $65,000,000.00   $262,797,249.00
# 2  31357  Waiting to Exhale  $16,000,000.00    $81,452,156.00
# 3    949               Heat  $60,000,000.00   $187,436,818.00
# 4   9091       Sudden Death  $35,000,000.00    $64,350,171.00
#
#   Original Language  Popularity        Production Countries  \
# 0                en   21.946943    United States of America
# 1                en   17.015539    United States of America
# 2                en    3.859495    United States of America
# 3                en   17.924927    United States of America
# 4                en    5.231580    United States of America
#
#                       Production Companies    Genre 1    Genre 2  ...  \
# 0                  Pixar Animation Studios  Animation     Comedy  ...
# 1                         TriStar Pictures  Adventure    Fantasy  ...
# ...

# %%
duplicates = moviesdf[moviesdf.duplicated()] 

print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Id, Title,  Budget ,  Revenue , Original Language, Popularity, Production Countries, Production Companies, Genre 1, Genre 2, Genre 3, Genre 4, Release Date, Runtime, Status, Tagline, Vote Average, Vote Count, Unnamed: 18, Unnamed: 19, Unnamed: 20, Unnamed: 21, Unnamed: 22, Unnamed: 23]
# Index: []
#
# [0 rows x 24 columns]

# %%
moviesdf.to_csv('cleaned_movies.csv')
